# %% [markdown]
# # Plot hourly mean temperatures
# - This script is used to plot hourly mean ground temperature, canopy air temperature, and ground temperature from simulations;
# - Simulations: CNTL, TRAF at FR-Capitole and UK-Manchester.

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import string
home_path = '/gws/nopw/j04/duicv/yuansun/'

# %%
df_delta = pd.read_csv('data_for_figure/delta_temperature_diurnal_mean.csv')
df_delta.head()
# Out:
#       value  hour    site  season          var
# 0  0.473556     0  FR-Cap  Summer  TRAFFICFLUX
# 1  0.474415     1  FR-Cap  Summer  TRAFFICFLUX
# 2  0.157867     2  FR-Cap  Summer  TRAFFICFLUX
# 3  0.157888     3  FR-Cap  Summer  TRAFFICFLUX
# 4  0.052694     4  FR-Cap  Summer  TRAFFICFLUX

# %%
df_traffic = df_delta[df_delta['var'] == 'TRAFFICFLUX']
df_traffic
# Out:
#         value  hour    site  season          var
# 0    0.473556     0  FR-Cap  Summer  TRAFFICFLUX
# 1    0.474415     1  FR-Cap  Summer  TRAFFICFLUX
# 2    0.157867     2  FR-Cap  Summer  TRAFFICFLUX
# 3    0.157888     3  FR-Cap  Summer  TRAFFICFLUX
# 4    0.052694     4  FR-Cap  Summer  TRAFFICFLUX
# ..        ...   ...     ...     ...          ...
# 307  0.832717    19  UK-MCR  Winter  TRAFFICFLUX
# 308  0.666196    20  UK-MCR  Winter  TRAFFICFLUX
# 309  0.499574    21  UK-MCR  Winter  TRAFFICFLUX
# 310  0.499983    22  UK-MCR  Winter  TRAFFICFLUX
# 311  0.500564    23  UK-MCR  Winter  TRAFFICFLUX
#
# [96 rows x 5 columns]

# %%
var_list = ['TG_U', 'TSA_U', 'TBUILD']
variable_list = [r'$T_\mathrm{grd}$', r'$T_\mathrm{air}$', 
                 r'$T_\mathrm{b}$', r'$Q_\mathrm{traffic}$']
site_list = ['FR-Cap', 'UK-MCR']
season_list = ['Summer', 'Winter']
period_list = ['JJA mean', 'DJF mean']
ncol = 2
nrow = 2
linewidth = 0.5
linestyle_list = ['dashed', 'solid']
case_list = ['cntl', 'traffic']
fontsize = 6
labelcolor = '#6b6b6b'
lc0 = '#1b9e77'
lc1 = '#d95f02'
lc2 = '#e7298a'
lc3 = '#e7298a'
#diff_lc = '#b60bc1'
diff_lc = '#7570b3'
lc = [lc0, lc1, lc2]
handletextpad = 0.5
label_list = ['CTNL', 'TRAF']
alpha=0.1
padding = 4
sitename_list = ['FR-Capitole', 'UK-Manchester']
xwidth = 0.5
labelfont = 6
pad = 1
length = 2
x_offset = 0.1
marker = 'o'
markersize = 1

# %%
fig, axes = plt.subplots(nrow, ncol, figsize=(5.5, 3))
ax = axes.flatten()
for i in range(ncol*nrow):
    site = site_list[i//ncol]
    season = season_list[i%ncol]
    df_site_season = df_delta[(df_delta['site'] == site) & (df_delta['season'] == season)]
    for v, var in enumerate(var_list):
        df_var = df_site_season[df_site_season['var'] == var]
        if df_var['value'].any()>0:
            #value = (df_var['value']-df_var['value'].min()) / (df_var['value'].max()-df_var['value'].min())
            value = df_var['value']
            ax[i].scatter(df_var['hour'], value, color=lc[v], marker=marker, s=markersize/2)
            ax[i].fill_between(df_var['hour'], value, 
                               color=lc[v], alpha=0.15, linewidth=linewidth, label = r'$\Delta$' + variable_list[v]) #edgecolor='none'
            ax[i].text(0.1 + x_offset*v, 0.9, np.round(value.mean(),2), fontsize=fontsize, color=lc[v], ha='center', va='center', transform=ax[i].transAxes)
    ax2 = ax[i].twinx() 
    for spine in ax2.spines.values():   
        spine.set_visible(False)
    ax2.tick_params(axis='y', which='both', left=False, right=True, labelleft=False, labelcolor=diff_lc, color=diff_lc,labelsize=labelfont,pad=pad, width = xwidth, length = length)     
    ax2.set_ylim(0, 1)
    ax2.set_yticks(np.arange(0, 1.1, 0.25))
    target_traffic = df_traffic[(df_traffic['site'] == site) & (df_traffic['season'] == season)]
    ax2.plot(target_traffic['hour'], target_traffic['value'], color=diff_lc, linestyle = 'dashed', 
             linewidth=linewidth, label = r'Normalized $Q_\mathrm{traffic}$', marker=marker, markersize=markersize)
    ax2.set_ylabel('Unitless',labelpad=5, rotation=0, ha='center', fontsize=labelfont,color=diff_lc)
    ax2.yaxis.set_label_coords(1.025, 1.125)
    ax[i].set_ylim(0, 0.8)
    ax[i].set_xlim(0, 23)
    ax[i].set_xticks([0, 6, 12, 18, 23])            
    #ax[i].set_xticklabels(np.arange(0, 24, 2), fontsize=fontsize)
    ax[i].set_xticklabels(['00:00', '06:00', '12:00', '18:00', '23:00'], fontsize=fontsize)
    ax[i].set_xticks(np.arange(0, 24, 3), minor=True)
    ax[i].set_title(f'({string.ascii_lowercase[i]}) {period_list[i%ncol]} at {sitename_list[i//ncol]}', fontsize=fontsize, color=labelcolor, pad=padding)
    for s, spine in enumerate(ax[i].spines.values()):
        spine.set_linewidth(xwidth)
        spine.set_edgecolor([labelcolor, diff_lc, labelcolor, labelcolor][s])
    ax[i].tick_params(axis='y', which='both', left=True, right=False, labelleft=True, labelcolor=labelcolor, color=labelcolor,labelsize=labelfont,pad=pad, width = xwidth, length = length)
    ax[i].tick_params(axis='x', which='both', top=False, bottom=True, labelbottom=True, labelcolor=labelcolor,color=labelcolor,labelsize=labelfont,pad=pad, width = xwidth, length = length)  
    ax[i].grid(True,which='both',linestyle='--',linewidth=0.5, alpha=0.5)  
    ax[i].set_ylabel('°C',labelpad=5, rotation=0, ha='center', fontsize=labelfont,color=labelcolor)
    ax[i].yaxis.set_label_coords(-0.05, 1.05)
lines1, labels1 = ax[0].get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines = lines1 + lines2
labels = labels1 + labels2
legend = fig.legend(lines, labels, bbox_to_anchor=(0.5, -0.015), loc='lower center', frameon=False, 
                        handletextpad=handletextpad, fontsize=fontsize, ncol=4)
for i, text in enumerate(legend.get_texts()):
    text.set_color((lc+ [diff_lc])[i])
plt.subplots_adjust(left=0.035, right=0.95, bottom=0.1, top=0.95, wspace=0.2, hspace= 0.3)    
fig.savefig('delta_diurnal_mean.png', dpi=300)
fig.savefig('delta_diurnal_mean.pdf', dpi=600)

# %% [markdown]
# # Describe

# %%
df_hour = pd.read_csv('data_for_figure/temperature_diurnal.csv')
df_winter = df_hour[df_hour['season'] == 'Winter']
df_winter_tair = df_winter[df_winter['var'] == 'TSA_U']
df_winter_tair_cntl = df_winter_tair[df_winter_tair['case'] == 'cntl']
df_winter_tair_cntl
# Out:
#      hour     value    site  season  case    var
# 96      0  5.321320  FR-Cap  Winter  cntl  TSA_U
# 97      1  5.157654  FR-Cap  Winter  cntl  TSA_U
# 98      2  4.887207  FR-Cap  Winter  cntl  TSA_U
# 99      3  4.727875  FR-Cap  Winter  cntl  TSA_U
# 100     4  4.541016  FR-Cap  Winter  cntl  TSA_U
# 101     5  4.359314  FR-Cap  Winter  cntl  TSA_U
# 102     6  4.239136  FR-Cap  Winter  cntl  TSA_U
# 103     7  4.151764  FR-Cap  Winter  cntl  TSA_U
# 104     8  4.041443  FR-Cap  Winter  cntl  TSA_U
# 105     9  4.059570  FR-Cap  Winter  cntl  TSA_U
# 106    10  4.691315  FR-Cap  Winter  cntl  TSA_U
# 107    11  5.936035  FR-Cap  Winter  cntl  TSA_U
# 108    12  6.807465  FR-Cap  Winter  cntl  TSA_U
# 109    13  7.800964  FR-Cap  Winter  cntl  TSA_U
# 110    14  8.559784  FR-Cap  Winter  cntl  TSA_U
# 111    15  8.887726  FR-Cap  Winter  cntl  TSA_U
# 112    16  8.957977  FR-Cap  Winter  cntl  TSA_U
# 113    17  8.466675  FR-Cap  Winter  cntl  TSA_U
# 114    18  7.942444  FR-Cap  Winter  cntl  TSA_U
# 115    19  7.200073  FR-Cap  Winter  cntl  TSA_U
# 116    20  6.629791  FR-Cap  Winter  cntl  TSA_U
# 117    21  6.310913  FR-Cap  Winter  cntl  TSA_U
# 118    22  5.919189  FR-Cap  Winter  cntl  TSA_U
# 119    23  5.544983  FR-Cap  Winter  cntl  TSA_U
# 432     0  4.985565  UK-MCR  Winter  cntl  TSA_U
# 433     1  4.957153  UK-MCR  Winter  cntl  TSA_U
# 434     2  4.846893  UK-MCR  Winter  cntl  TSA_U
# 435     3  4.744415  UK-MCR  Winter  cntl  TSA_U
# 436     4  4.693939  UK-MCR  Winter  cntl  TSA_U
# 437     5  4.643829  UK-MCR  Winter  cntl  TSA_U
# 438     6  4.561188  UK-MCR  Winter  cntl  TSA_U
# 439     7  4.598206  UK-MCR  Winter  cntl  TSA_U
# 440     8  4.572845  UK-MCR  Winter  cntl  TSA_U
# 441     9  4.657471  UK-MCR  Winter  cntl  TSA_U
# 442    10  5.080597  UK-MCR  Winter  cntl  TSA_U
# 443    11  6.003113  UK-MCR  Winter  cntl  TSA_U
# 444    12  6.857208  UK-MCR  Winter  cntl  TSA_U
# 445    13  7.495483  UK-MCR  Winter  cntl  TSA_U
# 446    14  7.780182  UK-MCR  Winter  cntl  TSA_U
# 447    15  7.680603  UK-MCR  Winter  cntl  TSA_U
# 448    16  7.233734  UK-MCR  Winter  cntl  TSA_U
# 449    17  6.666534  UK-MCR  Winter  cntl  TSA_U
# 450    18  6.221252  UK-MCR  Winter  cntl  TSA_U
# 451    19  5.885834  UK-MCR  Winter  cntl  TSA_U
# 452    20  5.624878  UK-MCR  Winter  cntl  TSA_U
# 453    21  5.402985  UK-MCR  Winter  cntl  TSA_U
# 454    22  5.212280  UK-MCR  Winter  cntl  TSA_U
# 455    23  5.084015  UK-MCR  Winter  cntl  TSA_U

# %%
df_winter_tair_traffic = df_winter_tair[df_winter_tair['case'] == 'traffic']
df_winter_tair_traffic
# Out:
#      hour     value    site  season     case    var
# 288     0  5.962524  FR-Cap  Winter  traffic  TSA_U
# 289     1  5.784973  FR-Cap  Winter  traffic  TSA_U
# 290     2  5.488709  FR-Cap  Winter  traffic  TSA_U
# 291     3  5.264648  FR-Cap  Winter  traffic  TSA_U
# 292     4  5.020721  FR-Cap  Winter  traffic  TSA_U
# 293     5  4.773895  FR-Cap  Winter  traffic  TSA_U
# 294     6  4.615509  FR-Cap  Winter  traffic  TSA_U
# 295     7  4.520783  FR-Cap  Winter  traffic  TSA_U
# 296     8  4.433075  FR-Cap  Winter  traffic  TSA_U
# 297     9  4.524231  FR-Cap  Winter  traffic  TSA_U
# 298    10  5.269134  FR-Cap  Winter  traffic  TSA_U
# 299    11  6.464233  FR-Cap  Winter  traffic  TSA_U
# 300    12  7.262360  FR-Cap  Winter  traffic  TSA_U
# 301    13  8.198273  FR-Cap  Winter  traffic  TSA_U
# 302    14  8.939087  FR-Cap  Winter  traffic  TSA_U
# 303    15  9.241791  FR-Cap  Winter  traffic  TSA_U
# 304    16  9.329803  FR-Cap  Winter  traffic  TSA_U
# 305    17  8.860870  FR-Cap  Winter  traffic  TSA_U
# 306    18  8.375275  FR-Cap  Winter  traffic  TSA_U
# 307    19  7.731720  FR-Cap  Winter  traffic  TSA_U
# 308    20  7.210419  FR-Cap  Winter  traffic  TSA_U
# 309    21  6.917938  FR-Cap  Winter  traffic  TSA_U
# 310    22  6.565949  FR-Cap  Winter  traffic  TSA_U
# 311    23  6.198181  FR-Cap  Winter  traffic  TSA_U
# 624     0  5.448517  UK-MCR  Winter  traffic  TSA_U
# 625     1  5.381592  UK-MCR  Winter  traffic  TSA_U
# 626     2  5.242004  UK-MCR  Winter  traffic  TSA_U
# 627     3  5.114807  UK-MCR  Winter  traffic  TSA_U
# 628     4  5.020874  UK-MCR  Winter  traffic  TSA_U
# 629     5  4.935913  UK-MCR  Winter  traffic  TSA_U
# 630     6  4.835602  UK-MCR  Winter  traffic  TSA_U
# 631     7  4.869232  UK-MCR  Winter  traffic  TSA_U
# 632     8  4.869202  UK-MCR  Winter  traffic  TSA_U
# 633     9  5.004944  UK-MCR  Winter  traffic  TSA_U
# 634    10  5.480499  UK-MCR  Winter  traffic  TSA_U
# 635    11  6.455749  UK-MCR  Winter  traffic  TSA_U
# 636    12  7.298737  UK-MCR  Winter  traffic  TSA_U
# 637    13  7.872894  UK-MCR  Winter  traffic  TSA_U
# 638    14  8.099365  UK-MCR  Winter  traffic  TSA_U
# 639    15  7.955170  UK-MCR  Winter  traffic  TSA_U
# 640    16  7.480743  UK-MCR  Winter  traffic  TSA_U
# 641    17  6.926971  UK-MCR  Winter  traffic  TSA_U
# 642    18  6.521149  UK-MCR  Winter  traffic  TSA_U
# 643    19  6.281555  UK-MCR  Winter  traffic  TSA_U
# 644    20  6.052551  UK-MCR  Winter  traffic  TSA_U
# 645    21  5.865662  UK-MCR  Winter  traffic  TSA_U
# 646    22  5.677734  UK-MCR  Winter  traffic  TSA_U
# 647    23  5.543152  UK-MCR  Winter  traffic  TSA_U
